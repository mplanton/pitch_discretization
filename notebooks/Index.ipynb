# %% [markdown]
# # Index: Reshift pitch discretization effect
#
# These notebooks document the exploration and testing of signal processing techiques that lead to the used algorithms in the "reshift" pitch discretization effect.
#
#
# [Algorithms and Parameters](Algorithms_and_Parameters.ipynb)
#
# Exploration of the used algorithms and parameters in "reshift".
#
# * pYIN pitch tracking
#
# * nonlinear frequency scales
#
# * librosas pYIN implementation: data synchronization
#
#
# ## Algorithms Synchronization
#
# How to synchronize the pYIN output with the "Rollers" pitch-shifting algorithm.
# It turned out, that _upsampling_ and knowledge about _frequency modulation_ is needed for this task.
#
# [Synchronize Control Rate and Audio Rate](Synchronize_Control_Rate_and_Audio_Rate.ipynb)
#
# * upsampling techniques
#
# * frequency modulation (FM)
#
# * FM: processing of an arbitrary modulator function via numeric integration
#
# * Upsampling for Frequency Modulation
#
#
# ## Used techniques in the "Rollers" pitch shifting algorithm
#
# [Filter Bank Design](Filter_Bank_Design.ipynb)
#
# * analog and digital IIR filter design
#
# * Filtering
#
# * constant Q Filterbank design
#
#
# [Frequency Shifting](Frequency_Shifting.ipynb)
#
# * amplitude modulation (AM)
#
# * Hilbert transform
#
# * the analytic signal
#
# * Single Sideband Modulation (SSB)
#
# * audio frequency shifting
#
#
# [Rollers pitch-shift](Rollers_pitch-shift.ipynb)
#
# Here the "Rollers" pitch-shifting algorithm is implemented in python using the techniques from above.
#
# * prototype design
#
# * using different filter banks
#
# * implementing time variant pitch-shifting
#
#
# [Testing](Testing.ipynb)
#
# esting the Reshift pitch discretization effect in terms of
#
# * parameters
#
# * sound quality and artifacts
#
# * performance
